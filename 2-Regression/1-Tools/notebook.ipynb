# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
X, y = datasets.load_linnerud(return_X_y=True)
print(X.shape)
print(y.shape)
print(X[0])
print(y[0])
# Out:
# (20, 3)
# (20, 3)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_20328\1568074977.py in <module>
#       2 print(X.shape)
#       3 print(y.shape)
# ----> 4 print(X[10000000000000000000000000000000000000000000000000000])
#       5 print(y[0])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X = X[:, np.newaxis, 1]
y = y[:, np.newaxis, 1]
print(X.shape)
print(X[0])
print(y.shape)
print(y[0])
# Out:
# (20, 1)
# [162.]
# (20, 1)
# [36.]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color = 'blue', linewidth=3)
plt.xlabel('Situps')
plt.ylabel('Waistline')
plt.title('A Graph Plot Showing Waistline Against Situps')
plt.show()
